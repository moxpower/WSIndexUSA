# %% [markdown]
# US Water Stress Index for 3 different years

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('precision',3)

# %%
pop=pd.read_csv('population.csv',header=0,names=['state_or_territory',1990,2000,2010])

# %%
pop[:3]
# Out:
#   state_or_territory      1990      2000      2010
# 0         California  38332521  37253956  33871648
# 1              Texas  26448193  25145561  20851820
# 2           New York  19651127  19378102  18976457

# %%
len(pop[1990])
# Out:
# 56

# %%
pop[1990]=pd.Series(np.random.randint(100,size=len(pop[1990])))/120
pop[2000]=pop[1990]+0.1
pop[2010]=pop[2000]+0.1

# %%
pop[1990]=pd.Series(np.random.randint(100,size=len(pop[1990])))/120
pop[2000]=pd.Series(np.random.randint(100,size=len(pop[2000])))/120
pop[2010]=pd.Series(np.random.randint(100,size=len(pop[2010])))/120

# %%
pop[:3]
# Out:
#   state_or_territory  1990  2000  2010
# 0         California  0.35  0.75  0.80
# 1              Texas  0.25  0.80  0.78
# 2           New York  0.47  0.59  0.28

# %%
pop.to_csv('wsindex.csv',index=False, float_format='%1.2f')

# %%
dsv=pd.read_csv('wsindex.csv')

# %%
dsv
# Out:
#           state_or_territory  1990  2000  2010
# 0                 California  0.35  0.75  0.80
# 1                      Texas  0.25  0.80  0.78
# 2                   New York  0.47  0.59  0.28
# 3                    Florida  0.04  0.65  0.53
# 4                   Illinois  0.26  0.51  0.14
# 5               Pennsylvania  0.31  0.26  0.53
# 6                       Ohio  0.42  0.38  0.74
# 7                    Georgia  0.26  0.47  0.32
# 8                   Michigan  0.33  0.19  0.35
# 9             North Carolina  0.68  0.68  0.70
# 10                New Jersey  0.72  0.31  0.07
# 11                  Virginia  0.67  0.28  0.48
# 12                Washington  0.44  0.82  0.72
# 13             Massachusetts  0.32  0.77  0.21
# 14                   Arizona  0.24  0.76  0.20
# 15                   Indiana  0.10  0.22  0.49
# 16                 Tennessee  0.49  0.63  0.59
# 17                  Missouri  0.82  0.17  0.03
# 18                  Maryland  0.68  0.32  0.81
# ...

# %% [markdown]
# csv=np.arange(4).reshape(2,2)
